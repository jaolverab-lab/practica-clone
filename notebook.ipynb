# %%
import sys
sys.executable
# Out:
# '/opt/anaconda3/envs/Mini_taller/bin/python'

# %%
1 + 1
# Out:
# 2

# %%
import matplotlib
import matplotlib.pyplot as plt

matplotlib.__version__
# Out:
# '3.10.8'

# %%
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

plt.scatter(x, y)
plt.title("Scatter simple")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
